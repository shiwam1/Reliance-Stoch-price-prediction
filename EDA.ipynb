# %% [markdown]
# # Business Objective:-
#
# Predict the Reliance Industries Stock Price for the next 30 days.
#
# There are Open, High, Low and Close prices that you need to obtain from the web for  day starting from 2015 to 2022 for Reliance Industries stock.

# %% [markdown]
# # Table of Contents
#
# 1. Importing Libraries
#
#
# 2. Importing Dataset
#
#
# 3. EDA (Exploratory Data Analysis)
#
#
# 4. Visualization

# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd
import numpy  as np
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ## 2. Importing Dataset

# %%
data = pd.read_csv("D:/Project-3/Reliance_stock_price.csv")
data
# Out:
#       Unnamed: 0        Date         Open         High          Low  \
# 0              0  01-01-2015   438.988831   441.812073   437.676269
# 1              1  02-01-2015   439.880371   443.818054   437.998199
# 2              2  05-01-2015   438.344940   441.267212   432.946106
# 3              3  06-01-2015   430.915344   432.401276   412.093750
# 4              4  07-01-2015   414.619812   425.367950   414.570282
# ...          ...         ...          ...          ...          ...
# 1971        1971  26-12-2022  2514.750000  2542.000000  2492.399902
# 1972        1972  27-12-2022  2530.000000  2548.800049  2515.250000
# 1973        1973  28-12-2022  2538.000000  2549.800049  2521.500000
# 1974        1974  29-12-2022  2527.000000  2548.899902  2525.500000
# 1975        1975  30-12-2022  2545.100098  2577.000000  2541.100098
#
#             Close    Adj Close   Volume
# 0      439.781311   417.988953  1367720
# 1      438.617340   416.882599  3383424
# ...

# %%
data = data.drop("Unnamed: 0", axis=1)
data
# Out:
#             Date         Open         High          Low        Close  \
# 0     01-01-2015   438.988831   441.812073   437.676269   439.781311
# 1     02-01-2015   439.880371   443.818054   437.998199   438.617340
# 2     05-01-2015   438.344940   441.267212   432.946106   433.812897
# 3     06-01-2015   430.915344   432.401276   412.093750   414.124512
# 4     07-01-2015   414.619812   425.367950   414.570282   423.139069
# ...          ...          ...          ...          ...          ...
# 1971  26-12-2022  2514.750000  2542.000000  2492.399902  2524.050049
# 1972  27-12-2022  2530.000000  2548.800049  2515.250000  2544.699951
# 1973  28-12-2022  2538.000000  2549.800049  2521.500000  2544.449951
# 1974  29-12-2022  2527.000000  2548.899902  2525.500000  2543.300049
# 1975  30-12-2022  2545.100098  2577.000000  2541.100098  2547.199951
#
#         Adj Close   Volume
# 0      417.988953  1367720
# 1      416.882599  3383424
# 2      412.316254  4662967
# ...

# %% [markdown]
# Observations :-
#
# The dataset used is Reliance Industries stock market data from NSE (National Stock Exchange) India over the last 7 years (2015 - 2022)
#
# The dataset contains 1976 samples. Each sample contains 7 features.
#
# 1. Date - Date of trade
#
#
# 2. Open - The open is the starting period of trading on a securities exchange or organized over-the-counter market.
#
#
# 3. High - Highest price at which a stock traded during the course of the trading day.
#
#
# 4. Low - Lowest price at which a stock traded during the course of the trading day.
#
#
# 5. Close - (Target variable) The close is a reference to the end of a trading session in the financial markets when the markets close for the day.
#
#
# 6. Adj.close - The price of the stock after paying off the dividends.
#
#
# 7. Volume - It is the amount of a security that was traded during a given period of time

# %% [markdown]
# ## 3. EDA (Exploratory Data Analysis)

# %%
data.shape
# Out:
# (1976, 7)

# %% [markdown]
# Observations :-
#
# 1. The data contains a total of 7 features for 1976 days.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1976 entries, 0 to 1975
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1976 non-null   object
#  1   Open       1976 non-null   float64
#  2   High       1976 non-null   float64
#  3   Low        1976 non-null   float64
#  4   Close      1976 non-null   float64
#  5   Adj Close  1976 non-null   float64
#  6   Volume     1976 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 108.2+ KB

# %% [markdown]
# Observations :-
#
# 1. The given data does not contain any 'nan' values hence we don't have any missing values, also the data types are correct.

# %%
data.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data[data.duplicated()].shape
# Out:
# (0, 7)

# %% [markdown]
# Observations :-
#
# The given dataset does not contain any duplicate rows.

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1976.000000  1976.000000  1976.000000  1976.000000  1976.000000
# mean   1315.801554  1330.795265  1300.182944  1314.889481  1300.448646
# std     752.202151   760.497187   743.372182   751.597730   755.782724
# min     404.466065   405.010895   394.485657   401.568542   381.669708
# 25%     530.180679   537.337814   525.989166   531.945190   516.012375
# 50%    1171.396301  1187.840454  1151.435546  1171.445861  1155.124573
# 75%    2043.350037  2065.924988  2003.612518  2034.700012  2023.652771
# max    2856.149902  2856.149902  2786.100098  2819.850098  2811.385742
#
#              Volume
# count  1.976000e+03
# mean   9.088830e+06
# std    6.693435e+06
# min    7.871600e+05
# 25%    5.242449e+06
# 50%    7.149341e+06
# 75%    1.024994e+07
# max    6.584835e+07

# %% [markdown]
# Observations :-
#
# 1. For all the columns the mean value is greater than the median value (50% percentile) so we can say that the dataset is positively skewed in nature.

# %% [markdown]
# ## 4. Visualization

# %% [markdown]
# ### 4.1 Histogram for 'Open', 'High', 'Low' , Close'

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(15,18))

plt.subplot(221)
data["Open"].hist(color='navy')
plt.xlabel("Opning Trend")
plt.ylabel("frequency")
plt.title ("Histogram for Opning Trend of Stock", color='brown')

plt.subplot(222)
data["High"].hist(color='navy')
plt.xlabel("Highest Price")
plt.ylabel("frequency")
plt.title ("Histogram for Highest Price of Stock", color='brown')

plt.subplot(223)
data["Low"].hist(color='navy')
plt.xlabel("Lowest Price")
plt.ylabel("frequency")
plt.title ("Histogram for Lowest Pric of Stock", color='brown')

plt.subplot(224)
data["Close"].hist(color='navy')
plt.xlabel("Closing Price")
plt.ylabel("frequency")
plt.title ("Histogram for Closing Price of Stock", color='brown')

plt.show()

# %% [markdown]
# Observations :-
#
# 1. By analysing the above histograms we can say that the given dataset is not symmetric in nature.

# %% [markdown]
# ### 4.2 Boxplot for 'Open', 'High', 'Low' , Close'

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

numerical_features_name = data[["Open", "High", "Low", "Close"]]

i=0
fig = make_subplots( rows=1, cols = numerical_features_name.shape[1],subplot_titles = numerical_features_name.columns.values )
for feature in numerical_features_name.columns.values:
    fig.add_trace(go.Box( y=numerical_features_name[feature]), row=1,col=i+1 )
    i = i+1

fig.update_layout( width=1000, height=500)
fig.show()
# Out:
# <div>                            <div id="8a99b380-9365-44d2-b056-fa95d5683f98" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a99b380-9365-44d2-b056-fa95d5683f98")) {                    Plotly.newPlot(                        "8a99b380-9365-44d2-b056-fa95d5683f98",                        [{"y":[438.9888306,439.8803711,438.3449402,430.9153442,414.619812,426.0118408,420.2167664,426.2099609,422.4951782,417.5421143,416.0562134,425.9623108,431.0144043,436.6113586,448.2510376,448.3253174,440.8214417,442.257843,438.8897705,449.2911682,460.633667,453.7241516,452.3125305,465.1409302,463.6054688,457.7113647,446.368866,444.783905,438.8402405,449.7369385,452.7087708,455.0367126,445.7745056,449.2168579,443.421814,430.8905945,423.1142883,420.4148865,419.07757
# ...

# %% [markdown]
# Observations :-
#
# 1. After analysing all the above box plots we can see that the given dataset does not contains noisy data points or outliers.

# %% [markdown]
# ### 4.3 'Open', 'High', 'Low' , Close' over the Time

# %%
cols_plot = ['Open', 'High','Low', 'Close']
axes = data[cols_plot].plot(figsize=(15, 12), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily trade')
    ax.set_xlabel('Date')

# %% [markdown]
# Observations :-
#
# 1. After analyzing all the above graphs we can say that all the trend follows the same pattern over the last 7 years.

# %% [markdown]
# ### 4.4 Kernel Distribution Estimation Plot (KDE)

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(15,18))

plt.subplot(221)
sns.kdeplot(data['Open'], shade=True, color='navy')

plt.subplot(222)
sns.kdeplot(data['High'], shade=True, color='navy')

plt.subplot(223)
sns.kdeplot(data['Low'], shade=True, color='navy')

plt.subplot(224)
sns.kdeplot(data['Close'], shade=True, color='navy')

plt.show()

# %% [markdown]
# Observations :-
#
# 1. For all the features density curve is right skewed and all the trend follows the same pattern.

# %%
fig = go.Figure([go.Scatter(x=data['Date'], y=data['Close'])])
fig.update_layout(
    autosize=False,
    width=1000,
    height=500,
    title='Closing Price over time',
    template="simple_white",
)

fig.update_xaxes(title="Date")
fig.update_yaxes(title="Close")
fig.show()
# Out:
# <div>                            <div id="df3a5fde-9775-4ce6-b85b-42246ad67b0e" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df3a5fde-9775-4ce6-b85b-42246ad67b0e")) {                    Plotly.newPlot(                        "df3a5fde-9775-4ce6-b85b-42246ad67b0e",                        [{"x":["01-01-2015","02-01-2015","05-01-2015","06-01-2015","07-01-2015","08-01-2015","09-01-2015","12-01-2015","13-01-2015","14-01-2015","15-01-2015","16-01-2015","19-01-2015","20-01-2015","21-01-2015","22-01-2015","23-01-2015","27-01-2015","28-01-2015","29-01-2015","30-01-2015","02-02-2015","03-02-2015","04-02-2015","05-02-2015","06-02-2015","09-02-2015","10-02-2015","11-02-2015","12-02-2015","13-02-2015","16-02-2015","18-02-2015","19-02-2015","20-02-2015","23-
# ...
